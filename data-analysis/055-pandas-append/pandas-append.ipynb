# %% [markdown]
# # Pandas append()
#
# This is a notebook for the medium article [Pandas append()](https://bindichen.medium.com/5-tricks-to-master-pandas-append-ede4318cc700)
#
# Please check out article for instructions
#
# **License**: [BSD 2-Clause](https://opensource.org/licenses/BSD-2-Clause)

# %%
import pandas as pd

# %% [markdown]
# ## 1. Appending a single row

# %%
df1 = pd.DataFrame({
    'name': ['A', 'B', 'C', 'D'],
    'math': [60,89,82,70],
    'physics': [66,95,83,66],
    'chemistry': [61,91,77,70]
})
df1
# Out:
#   name  math  physics  chemistry
# 0    A    60       66         61
# 1    B    89       95         91
# 2    C    82       83         77
# 3    D    70       66         70

# %% [markdown]
# ### Appending a series

# %%
### Appending a series
my_series = pd.Series(
    ['E', 60, 70, 80],  
    index=['name', 'math', 'physics', 'chemistry']
)

df1.append(my_series, ignore_index=True)
# Out:
#   name  math  physics  chemistry
# 0    A    60       66         61
# 1    B    89       95         91
# 2    C    82       83         77
# 3    D    70       66         70
# 4    E    60       70         80

# %% [markdown]
# ### Appending a dict

# %%
### Appending a dict
my_dict = {'name': 'E', 'math': 60, 'physics': 80, 'chemistry': 90 }

df1.append(my_dict, ignore_index=True)
# Out:
#   name  math  physics  chemistry
# 0    A    60       66         61
# 1    B    89       95         91
# 2    C    82       83         77
# 3    D    70       66         70
# 4    E    60       80         90

# %% [markdown]
# ### Appending a list - wrong

# %%
### Appending a list - wrong
my_list = ['E', 60, 70, 80]

df1.append(my_list, ignore_index=True)
# Out:
#      0  chemistry  math name  physics
# 0  NaN       61.0  60.0    A     66.0
# 1  NaN       91.0  89.0    B     95.0
# 2  NaN       77.0  82.0    C     83.0
# 3  NaN       70.0  70.0    D     66.0
# 4    E        NaN   NaN  NaN      NaN
# 5   60        NaN   NaN  NaN      NaN
# 6   70        NaN   NaN  NaN      NaN
# 7   80        NaN   NaN  NaN      NaN

# %% [markdown]
# ### Appending a list - correct

# %%
### Appending a list - correct

my_list = ['E', 60, 70, 80]

# Convert a lint to Pandas Series
a_series = pd.Series(my_list, index=df1.columns)

df1.append(a_series, ignore_index=True)
# Out:
#   name  math  physics  chemistry
# 0    A    60       66         61
# 1    B    89       95         91
# 2    C    82       83         77
# 3    D    70       66         70
# 4    E    60       70         80

# %% [markdown]
# ## 2. Appending multiple rows

# %%
df1 = pd.DataFrame({
    'name': ['A', 'B', 'C', 'D'],
    'math': [60,89,82,70],
    'physics': [66,95,83,66],
    'chemistry': [61,91,77,70]
})

# %%
df1
# Out:
#   name  math  physics  chemistry
# 0    A    60       66         61
# 1    B    89       95         91
# 2    C    82       83         77
# 3    D    70       66         70

# %% [markdown]
# ### 2.1. A DataFrame

# %%
# Create a DataFrame
df2 = pd.DataFrame({
    'name': ['E', 'F', 'G', 'H'],
    'math': [66,95,83,66],
    'physics': [60,89,82,70],
    'chemistry': [90,81,78,90]
})
df2
# Out:
#   name  math  physics  chemistry
# 0    E    66       60         90
# 1    F    95       89         81
# 2    G    83       82         78
# 3    H    66       70         90

# %%
df1.append(df2)
# Out:
#   name  math  physics  chemistry
# 0    A    60       66         61
# 1    B    89       95         91
# 2    C    82       83         77
# 3    D    70       66         70
# 0    E    66       60         90
# 1    F    95       89         81
# 2    G    83       82         78
# 3    H    66       70         90

# %%
# Ingore index
df1.append(df2, ignore_index=True)
# Out:
#   name  math  physics  chemistry
# 0    A    60       66         61
# 1    B    89       95         91
# 2    C    82       83         77
# 3    D    70       66         70
# 4    E    66       60         90
# 5    F    95       89         81
# 6    G    83       82         78
# 7    H    66       70         90

# %% [markdown]
# ### 2.2 A list of dict

# %%
## A list of dict
my_dict_list = [
  {'name' : 'E', 'math' : 66, 'physics' : 60, 'chemistry': 90 },
  {'name' : 'F', 'math' : 95, 'physics' : 89, 'chemistry': 81 },
  {'name' : 'G', 'math' : 83, 'physics' : 82, 'chemistry': 78 },
  {'name' : 'H', 'math' : 66, 'physics' : 70, 'chemistry': 90 }
]
my_dict_list
# Out:
# [{'name': 'E', 'math': 66, 'physics': 60, 'chemistry': 90},
#  {'name': 'F', 'math': 95, 'physics': 89, 'chemistry': 81},
#  {'name': 'G', 'math': 83, 'physics': 82, 'chemistry': 78},
#  {'name': 'H', 'math': 66, 'physics': 70, 'chemistry': 90}]

# %%
df1.append(my_dict_list, ignore_index=True)
# Out:
#   name  math  physics  chemistry
# 0    A    60       66         61
# 1    B    89       95         91
# 2    C    82       83         77
# 3    D    70       66         70
# 4    E    66       60         90
# 5    F    95       89         81
# 6    G    83       82         78
# 7    H    66       70         90

# %% [markdown]
# ### 2.3 A list of lists

# %%
# A list of lists
my_list_of_list = [
    ['E', 66, 60, 90],
    ['F', 95, 89, 81],
    ['G', 83, 82, 78],
    ['H', 66, 70, 90]
]

# %%
# Convert a list of lists to a DataFrame
my_df = pd.DataFrame(my_list_of_list, columns=df1.columns)
my_df
# Out:
#   name  math  physics  chemistry
# 0    E    66       60         90
# 1    F    95       89         81
# 2    G    83       82         78
# 3    H    66       70         90

# %%
df1.append(my_df, ignore_index=True)
# Out:
#   name  math  physics  chemistry
# 0    A    60       66         61
# 1    B    89       95         91
# 2    C    82       83         77
# 3    D    70       66         70
# 4    E    66       60         90
# 5    F    95       89         81
# 6    G    83       82         78
# 7    H    66       70         90

# %% [markdown]
# ## 3. When column names don't align

# %%
# Missing columns
my_dict_list_missing = [
  {'name' : 'E', 'chemistry': 90 },
  {'name' : 'F', 'math' : 95, },
  {'name' : 'G', 'math' : 83, 'physics' : 82,  },
  {'name' : 'H', 'math' : 66, 'chemistry': 90 }
]

# %% [markdown]
# ### Missing columns

# %%
df1.append(my_dict_list_missing, ignore_index=True)
# Out:
#   name  math  physics  chemistry
# 0    A  60.0     66.0       61.0
# 1    B  89.0     95.0       91.0
# 2    C  82.0     83.0       77.0
# 3    D  70.0     66.0       70.0
# 4    E   NaN      NaN       90.0
# 5    F  95.0      NaN        NaN
# 6    G  83.0     82.0        NaN
# 7    H  66.0      NaN       90.0

# %% [markdown]
# ### New columns

# %%
# New columns
my_dict_list_new = [
  {'name' : 'E', 'math' : 66, 'physics' : 60, 'chemistry': 90, 'biology': 80 },
  {'name' : 'F', 'math' : 95, 'physics' : 89, 'chemistry': 81, 'biology': 60},
  {'name' : 'G', 'math' : 83, 'physics' : 82, 'chemistry': 78, 'biology': 65 },
  {'name' : 'H', 'math' : 66, 'physics' : 70, 'chemistry': 90, 'biology': 80}
]

# %%
df1.append(my_dict_list_new, ignore_index=True)
# Out:
#   name  math  physics  chemistry  biology
# 0    A    60       66         61      NaN
# 1    B    89       95         91      NaN
# 2    C    82       83         77      NaN
# 3    D    70       66         70      NaN
# 4    E    66       60         90     80.0
# 5    F    95       89         81     60.0
# 6    G    83       82         78     65.0
# 7    H    66       70         90     80.0

# %% [markdown]
# ## 4. Sorting columns with `sort=True`
#
# Optional, default False. If True, sorts columns

# %%
df1.append(df2, ignore_index=True, sort=True)
# Out:
#    chemistry  math name  physics
# 0         61    60    A       66
# 1         91    89    B       95
# 2         77    82    C       83
# 3         70    70    D       66
# 4         90    66    E       60
# 5         81    95    F       89
# 6         78    83    G       82
# 7         90    66    H       70

# %% [markdown]
# ## 5. Avoid appending rows with the same index with `verify_integrity=True`
#
# Optional, default False. If True, you will get an error if you have two or more rows with the same index

# %%
# Create a DataFrame
df2 = pd.DataFrame({
    'name': ['E', 'F', 'G', 'H'],
    'math': [66,95,83,66],
    'physics': [60,89,82,70],
    'chemistry': [90,81,78,90]
}, index=[1, 4, 5, 6])
df2
# Out:
#   name  math  physics  chemistry
# 1    E    66       60         90
# 4    F    95       89         81
# 5    G    83       82         78
# 6    H    66       70         90

# %%
# Error Message: 
#   ValueError: Indexes have overlapping values: Int64Index([1], dtype='int64')
df1.append(df2, verify_integrity=True)
# Out:
# ---------------------------------------------------------------------------
# ValueError                                Traceback (most recent call last)
# <ipython-input-23-762e44c99e4f> in <module>
#       1 # Error Message:
#       2 #   ValueError: Indexes have overlapping values: Int64Index([1], dtype='int64')
# ----> 3 df1.append(df2, verify_integrity=True)
#
# ~/anaconda3/envs/tf-tutorial/lib/python3.7/site-packages/pandas/core/frame.py in append(self, other, ignore_index, verify_integrity, sort)
#    7749             ignore_index=ignore_index,
#    7750             verify_integrity=verify_integrity,
# -> 7751             sort=sort,
#    7752         )
#    7753
#
# ~/anaconda3/envs/tf-tutorial/lib/python3.7/site-packages/pandas/core/reshape/concat.py in concat(objs, axis, join, ignore_index, keys, levels, names, verify_integrity, sort, copy)
#     282         verify_integrity=verify_integrity,
#     283         copy=copy,
# --> 284         sort=sort,
#     285     )
#     286
#
# ~/anaconda3/envs/tf-tutorial/lib/python3.7/site-packages/pandas/core/reshape/concat.py in __init__(self, objs, axis, join, keys, levels, names, ignore_index, verify_integrity, copy, sort)
#     452         self.copy = copy
#     453
# --> 454         self.new_axes = self._get_new_axes()
#     455
#     456     def get_result(self):
#
# ~/anaconda3/envs/tf-tutorial/lib/python3.7/site-packages/pandas/core/reshape/concat.py in _get_new_axes(self)
#     519         return [
#     520             self._get_concat_axis() if i == self.bm_axis else self._get_comb_axis(i)
# --> 521             for i in range(ndim)
#     522         ]
#     523
#
# ~/anaconda3/envs/tf-tutorial/lib/python3.7/site-packages/pandas/core/reshape/concat.py in <listcomp>(.0)
#     519         return [
#     520             self._get_concat_axis() if i == self.bm_axis else self._get_comb_axis(i)
# --> 521             for i in range(ndim)
#     522         ]
#     523
#
# ~/anaconda3/envs/tf-tutorial/lib/python3.7/site-packages/pandas/core/reshape/concat.py in _get_concat_axis(self)
#     578             )
#     579
# --> 580         self._maybe_check_integrity(concat_axis)
#     581
#     582         return concat_axis
#
# ~/anaconda3/envs/tf-tutorial/lib/python3.7/site-packages/pandas/core/reshape/concat.py in _maybe_check_integrity(self, concat_index)
#     586             if not concat_index.is_unique:
#     587                 overlap = concat_index[concat_index.duplicated()].unique()
# --> 588                 raise ValueError(f"Indexes have overlapping values: {overlap}")
#     589
#     590
#
# ValueError: Indexes have overlapping values: Int64Index([1], dtype='int64')

# %% [markdown]
# ## Thanks for reading
#
#
# This is a notebook for the medium article [Pandas append()](https://bindichen.medium.com/5-tricks-to-master-pandas-append-ede4318cc700)
#
# Please check out article for instructions
#
# **License**: [BSD 2-Clause](https://opensource.org/licenses/BSD-2-Clause)
