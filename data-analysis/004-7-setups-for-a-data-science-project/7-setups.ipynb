# %% [markdown]
# # 7 setups you should include at the beginning of a data science project
#
# This is a notebook for the medium article [7 setups you should include at the beginning of a data science project](https://medium.com/@bindiatwork/7-setups-you-should-include-at-the-beginning-of-a-data-science-project-8232ab10a1ec)
#
# Please check out article for instructions
#
# **License**: [BSD 2-Clause](https://opensource.org/licenses/BSD-2-Clause)

# %% [markdown]
# ## Dataset Preparation

# %%
import pandas as pd
import numpy as np

def load_data():
    return pd.read_csv('data/train.csv')

df = load_data()

# %%
df.head()
# Out:
#    PassengerId  Survived  Pclass  \
# 0            1         0       3
# 1            2         1       1
# 2            3         1       3
# 3            4         1       1
# 4            5         0       3
#
#                                                 Name     Sex   Age  SibSp  \
# 0                            Braund, Mr. Owen Harris    male  22.0      1
# 1  Cumings, Mrs. John Bradley (Florence Briggs Th...  female  38.0      1
# 2                             Heikkinen, Miss. Laina  female  26.0      0
# 3       Futrelle, Mrs. Jacques Heath (Lily May Peel)  female  35.0      1
# 4                           Allen, Mr. William Henry    male  35.0      0
#
#    Parch            Ticket     Fare Cabin Embarked
# 0      0         A/5 21171   7.2500   NaN        S
# 1      0          PC 17599  71.2833   C85        C
# 2      0  STON/O2. 3101282   7.9250   NaN        S
# 3      0            113803  53.1000  C123        S
# 4      0            373450   8.0500   NaN        S

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 891 entries, 0 to 890
# Data columns (total 12 columns):
#  #   Column       Non-Null Count  Dtype
# ---  ------       --------------  -----
#  0   PassengerId  891 non-null    int64
#  1   Survived     891 non-null    int64
#  2   Pclass       891 non-null    int64
#  3   Name         891 non-null    object
#  4   Sex          891 non-null    object
#  5   Age          714 non-null    float64
#  6   SibSp        891 non-null    int64
#  7   Parch        891 non-null    int64
#  8   Ticket       891 non-null    object
#  9   Fare         891 non-null    float64
#  10  Cabin        204 non-null    object
#  11  Embarked     889 non-null    object
# dtypes: float64(2), int64(5), object(5)
# memory usage: 83.7+ KB

# %% [markdown]
# ## 1. Ensure Python version

# %%
import sys
sys.version
# Out:
# '3.7.6 (default, Jan  8 2020, 13:42:34) \n[Clang 4.0.1 (tags/RELEASE_401/final)]'

# %%
# Python ≥3.7 is required
import sys
assert sys.version_info >= (3, 7)

# %% [markdown]
# ## 2. Ensure package version

# %%
import pandas as pd
pd.__version__
# Out:
# '1.0.3'

# %%
import tensorflow as tf
tf.__version__
# Out:
# '2.0.0'

# %%
# TensorFlow ≥2.0 is required
import tensorflow as tf
assert tf.__version__ >= "2.0"

# %% [markdown]
# ## 3. Avoid blurry image

# %%
import seaborn as sns
import matplotlib.pyplot as plt
# %matplotlib inline

# Default figure format png
sns.heatmap(df.isnull(), 
            yticklabels=False, 
            cbar=False, 
            cmap='viridis')

# %%
# %config InlineBackend.figure_format = 'retina'

sns.heatmap(df.isnull(), 
            yticklabels=False, 
            cbar=False, 
            cmap='viridis')

# %%
# %config InlineBackend.figure_format = 'svg'

sns.heatmap(df.isnull(), 
            yticklabels=False, 
            cbar=False, 
            cmap='viridis')

# %% [markdown]
# ## 4. Multiple Cell Outputs

# %%
from IPython.core.interactiveshell import InteractiveShell
InteractiveShell.ast_node_interactivity = "all"

# %%
df.head()
df.info()
# Out:
#    PassengerId  Survived  Pclass  \
# 0            1         0       3
# 1            2         1       1
# 2            3         1       3
# 3            4         1       1
# 4            5         0       3
#
#                                                 Name     Sex   Age  SibSp  \
# 0                            Braund, Mr. Owen Harris    male  22.0      1
# 1  Cumings, Mrs. John Bradley (Florence Briggs Th...  female  38.0      1
# 2                             Heikkinen, Miss. Laina  female  26.0      0
# 3       Futrelle, Mrs. Jacques Heath (Lily May Peel)  female  35.0      1
# 4                           Allen, Mr. William Henry    male  35.0      0
#
#    Parch            Ticket     Fare Cabin Embarked
# 0      0         A/5 21171   7.2500   NaN        S
# 1      0          PC 17599  71.2833   C85        C
# 2      0  STON/O2. 3101282   7.9250   NaN        S
# 3      0            113803  53.1000  C123        S
# 4      0            373450   8.0500   NaN        S
# ...

# %% [markdown]
# ## 5. Keep output stable across runs

# %%
np.random.rand(4)
# Out:
# array([0.72805369, 0.46309521, 0.93319579, 0.70477743])

# %%
np.random.rand(4)
# Out:
# array([0.05309489, 0.16202395, 0.00443497, 0.18425868])

# %%
# reset seed
np.random.seed(0)
np.random.rand(4)
# Out:
# array([0.5488135 , 0.71518937, 0.60276338, 0.54488318])

# %%
# reset seed
np.random.seed(0)
np.random.rand(4)
# Out:
# array([0.5488135 , 0.71518937, 0.60276338, 0.54488318])

# %% [markdown]
# ## 6. Save plot locally

# %%
import os
# %matplotlib inline
import matplotlib.pyplot as plt

# Where to save the figures
PROJECT_ROOT_DIR = "."
SUB_FOLDER = "sub_folder"    # a sub-folder
IMAGES_PATH = os.path.join(PROJECT_ROOT_DIR, "images", SUB_FOLDER)

def save_fig(name, images_path=IMAGES_PATH, tight_layout=True, extension="png", resolution=300):
    if not os.path.isdir(images_path):
        os.makedirs(images_path)
    path = os.path.join(images_path, name + "." + extension)
    print("Saving figure:", name)
    if tight_layout:
        plt.tight_layout()
    plt.savefig(path, format=extension, dpi=resolution)

# %%
df.plot()
save_fig('figure_name')
# Out:
# Saving figure: figure_name

# %% [markdown]
# ## 7. Download and untar/unzip file

# %%
import os
import tarfile
import zipfile
import urllib
 
# Where to save the data
PROJECT_ROOT_DIR = "."
SUB_FOLDER = "group_name"
LOCAL_PATH = os.path.join(PROJECT_ROOT_DIR, "datasets", SUB_FOLDER)

def download(file_url, local_path = LOCAL_PATH):
    if not os.path.isdir(local_path):
        os.makedirs(local_path)
        
    # Download file
    print(">>> downloading ")
    filename = os.path.basename(file_url)
    file_local_path = os.path.join(local_path, filename)
    urllib.request.urlretrieve(file_url, file_local_path)
    
    # untar/unzip file 
    if filename.endswith("tgz") or filename.endswith("tar.gz"):
        print(">>> unpacking file:", filename)
        tar = tarfile.open(file_local_path, "r:gz")
        tar.extractall(path = local_path)
        tar.close()
    elif filename.endswith("tar"):
        tar = tarfile.open(file_local_path, "r:")
        tar.extractall(path = local_path)
        tar.close()
    elif filename.endwith("zip"):
        zip_file = zipfile.ZipFile(file_local_path)
        zip_file.extractall(path = local_path)
        zip_file.close()
    print("Done")

# %%
download("https://raw.githubusercontent.com/ageron/handson-ml2/master/datasets/housing/housing.tgz")
# Out:
# >>> downloading
# >>> unpacking file: housing.tgz
# Done
