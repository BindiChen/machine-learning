# %% [markdown]
# # Pandas json_normalize()
#
# This is a notebook for the medium article [Pandas json_normalize()](https://bindichen.medium.com/all-pandas-json-normalize-you-should-know-for-flattening-json-13eae1dfb7dd)
#
# Please check out article for instructions
#
# **License**: [BSD 2-Clause](https://opensource.org/licenses/BSD-2-Clause)

# %%
import pandas as pd

# %% [markdown]
# ## 1. Flattening a simple JSON

# %% [markdown]
# ### A dict

# %%
a_dict = {
    'school': 'ABC primary school',
    'location': 'London',
    'ranking': 2,
}

# %%
df = pd.json_normalize(a_dict)
df
# Out:
#                school location  ranking
# 0  ABC primary school   London        2

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 1 entries, 0 to 0
# Data columns (total 3 columns):
#  #   Column    Non-Null Count  Dtype
# ---  ------    --------------  -----
#  0   school    1 non-null      object
#  1   location  1 non-null      object
#  2   ranking   1 non-null      int64
# dtypes: int64(1), object(2)
# memory usage: 152.0+ bytes

# %% [markdown]
# ### A list of dicts

# %%
json_list = [
    { 'class': 'Year 1', 'num_of_students': 20, 'room': 'Yellow' },
    { 'class': 'Year 2', 'num_of_students': 25, 'room': 'Blue' },
]
pd.json_normalize(json_list)
# Out:
#     class  num_of_students    room
# 0  Year 1               20  Yellow
# 1  Year 2               25    Blue

# %%
# Missing field is represented as NaN
json_list = [
    { 'class': 'Year 1', 'num_of_students': 20, 'room': 'Yellow' },
    { 'class': 'Year 2', 'room': 'Blue' },
]
pd.json_normalize(json_list)
# Out:
#     class  num_of_students    room
# 0  Year 1             20.0  Yellow
# 1  Year 2              NaN    Blue

# %% [markdown]
# ## 2. Flattening a JSON with Multiple levels

# %% [markdown]
# ### A dict

# %%
a_obj = {
    'school': 'ABC primary school',
    'location': 'London',
    'ranking': 2,
    'info': {
        'president': 'John Kasich',
        'contacts': {
          'email': {
              'admission': 'admission@abc.com',
              'general': 'info@abc.com'
          },
          'tel': '123456789',
      }
    }
}

# %%
pd.json_normalize(a_obj)
# Out:
#                school location  ranking info.president  \
# 0  ABC primary school   London        2    John Kasich
#
#   info.contacts.email.admission info.contacts.email.general info.contacts.tel
# 0             admission@abc.com                info@abc.com         123456789

# %%
# If you don’t want to dig all the way down into each sub-object use the max_level argument.
pd.json_normalize(a_obj, max_level=1)
# Out:
#                school location  ranking info.president  \
# 0  ABC primary school   London        2    John Kasich
#
#                                        info.contacts
# 0  {'email': {'admission': 'admission@abc.com', '...

# %% [markdown]
# ### A list of dicts

# %%
json_list = [
    { 
        'class': 'Year 1', 
        'student count': 20, 
        'room': 'Yellow',
        'info': {
            'teachers': { 
                'math': 'Rick Scott', 
                'physics': 'Elon Mask' 
            }
        }
    },
    { 
        'class': 'Year 2', 
        'student count': 25, 
        'room': 'Blue',
        'info': {
            'teachers': { 
                'math': 'Alan Turing', 
                'physics': 'Albert Einstein' 
            }
        }
    },
]

pd.json_normalize(json_list)
# Out:
#     class  student count    room info.teachers.math info.teachers.physics
# 0  Year 1             20  Yellow         Rick Scott             Elon Mask
# 1  Year 2             25    Blue        Alan Turing       Albert Einstein

# %%
pd.json_normalize(json_list, max_level=1)
# Out:
#     class  student count    room  \
# 0  Year 1             20  Yellow
# 1  Year 2             25    Blue
#
#                                        info.teachers
# 0     {'math': 'Rick Scott', 'physics': 'Elon Mask'}
# 1  {'math': 'Alan Turing', 'physics': 'Albert Ein...

# %%
# with missing keys
json_list = [
    { 
        'class': 'Year 1', 
        'student count': 20, 
        'room': 'Yellow',
        'info': {
            'teachers': { 'math': 'Rick Scott', 'physics': 'Elon Mask' }
        }
    },
    { 
        'class': 'Year 2', 
        'student count': 25, 
        'room': 'Blue',
        'info': {
            'teachers': { 'physics': 'Albert Einstein' }
        }
    },
]

pd.json_normalize(json_list)
# Out:
#     class  student count    room info.teachers.math info.teachers.physics
# 0  Year 1             20  Yellow         Rick Scott             Elon Mask
# 1  Year 2             25    Blue                NaN       Albert Einstein

# %% [markdown]
# ## 3. Flattening a JSON with nested list

# %% [markdown]
# ### A dict

# %%
a_dict = {
    'school': 'ABC primary school',
    'location': 'London',
    'ranking': 2,
    'info': {
        'president': 'John Kasich',
        'contacts': {
          'email': {
              'admission': 'admission@abc.com',
              'general': 'info@abc.com'
          },
          'tel': '123456789',
      }
    },
    'students': [
      { 'name': 'Tom' },
      { 'name': 'James' },
      { 'name': 'Jacqueline' }
    ],
}

# %%
pd.json_normalize(a_dict)
# Out:
#                school location  ranking  \
# 0  ABC primary school   London        2
#
#                                             students info.president  \
# 0  [{'name': 'Tom'}, {'name': 'James'}, {'name': ...    John Kasich
#
#   info.contacts.email.admission info.contacts.email.general info.contacts.tel
# 0             admission@abc.com                info@abc.com         123456789

# %%
# Flatten students
pd.json_normalize(a_dict, record_path =['students'])
# Out:
#          name
# 0         Tom
# 1       James
# 2  Jacqueline

# %%
# Include meta data
pd.json_normalize(
    a_dict, 
    record_path =['students'],
    meta=['school', ['info', 'contacts', 'tel']],
)
# Out:
#          name              school info.contacts.tel
# 0         Tom  ABC primary school         123456789
# 1       James  ABC primary school         123456789
# 2  Jacqueline  ABC primary school         123456789

# %% [markdown]
# ### A list of dicts

# %%
json_list = [
    { 
        'class': 'Year 1', 
        'student count': 20, 
        'room': 'Yellow',
        'info': {
            'teachers': { 
                'math': 'Rick Scott', 
                'physics': 'Elon Mask' 
            }
        },
        'students': [
            { 
                'name': 'Tom', 
                'sex': 'M', 
                'grades': { 'math': 66, 'physics': 77 } 
            },
            { 
                'name': 'James', 
                'sex': 'M', 
                'grades': { 'math': 80, 'physics': 78 } 
            },
        ]
    },
    { 
        'class': 'Year 2', 
        'student count': 25, 
        'room': 'Blue',
        'info': {
            'teachers': { 
                'math': 'Alan Turing', 
                'physics': 'Albert Einstein' 
            }
        },
        'students': [
            { 'name': 'Tony', 'sex': 'M' },
            { 'name': 'Jacqueline', 'sex': 'F' },
        ]
    },
]

pd.json_normalize(json_list)
# Out:
#     class  student count    room  \
# 0  Year 1             20  Yellow
# 1  Year 2             25    Blue
#
#                                             students info.teachers.math  \
# 0  [{'name': 'Tom', 'sex': 'M', 'grades': {'math'...         Rick Scott
# 1  [{'name': 'Tony', 'sex': 'M'}, {'name': 'Jacqu...        Alan Turing
#
#   info.teachers.physics
# 0             Elon Mask
# 1       Albert Einstein

# %%
pd.json_normalize(json_list, record_path =['students'])
# Out:
#          name sex  grades.math  grades.physics
# 0         Tom   M         66.0            77.0
# 1       James   M         80.0            78.0
# 2        Tony   M          NaN             NaN
# 3  Jacqueline   F          NaN             NaN

# %%
pd.json_normalize(
    json_list, 
    record_path =['students'], 
    meta=['class', 'room', ['info', 'teachers', 'math']]
)
# Out:
#          name sex  grades.math  grades.physics   class    room  \
# 0         Tom   M         66.0            77.0  Year 1  Yellow
# 1       James   M         80.0            78.0  Year 1  Yellow
# 2        Tony   M          NaN             NaN  Year 2    Blue
# 3  Jacqueline   F          NaN             NaN  Year 2    Blue
#
#   info.teachers.math
# 0         Rick Scott
# 1         Rick Scott
# 2        Alan Turing
# 3        Alan Turing

# %% [markdown]
# ## 4. Ignoring KeyError if keys are not always present

# %%
data = [
    { 
        'class': 'Year 1', 
        'student count': 20, 
        'room': 'Yellow',
        'info': {
            'teachers': { 
                'math': 'Rick Scott', 
                'physics': 'Elon Mask',
            }
        },
        'students': [
            { 'name': 'Tom', 'sex': 'M' },
            { 'name': 'James', 'sex': 'M' },
        ]
    },
    { 
        'class': 'Year 2', 
        'student count': 25, 
        'room': 'Blue',
        'info': {
            'teachers': { 
                'physics': 'Albert Einstein'
            }
        },
        'students': [
            { 'name': 'Tony', 'sex': 'M' },
            { 'name': 'Jacqueline', 'sex': 'F' },
        ]
    },
]

# %%
pd.json_normalize(
    data, 
    record_path =['students'], 
    meta=['class', 'room', ['info', 'teachers', 'math']],
)
# Out:
# ---------------------------------------------------------------------------
# KeyError                                  Traceback (most recent call last)
# ~/anaconda3/envs/tf-tutorial/lib/python3.7/site-packages/pandas/io/json/_normalize.py in _recursive_extract(data, path, seen_meta, level)
#     323                         try:
# --> 324                             meta_val = _pull_field(obj, val[level:])
#     325                         except KeyError as e:
#
# ~/anaconda3/envs/tf-tutorial/lib/python3.7/site-packages/pandas/io/json/_normalize.py in _pull_field(js, spec)
#     236             for field in spec:
# --> 237                 result = result[field]
#     238         else:
#
# KeyError: 'math'
#
# The above exception was the direct cause of the following exception:
#
# KeyError                                  Traceback (most recent call last)
# <ipython-input-21-977290635fef> in <module>
#       2     data,
#       3     record_path =['students'],
# ----> 4     meta=['class', 'room', ['info', 'teachers', 'math']],
#       5 )
#
# ~/anaconda3/envs/tf-tutorial/lib/python3.7/site-packages/pandas/io/json/_normalize.py in _json_normalize(data, record_path, meta, meta_prefix, record_prefix, errors, sep, max_level)
#     334                 records.extend(recs)
#     335
# --> 336     _recursive_extract(data, record_path, {}, level=0)
#     337
#     338     result = DataFrame(records)
#
# ~/anaconda3/envs/tf-tutorial/lib/python3.7/site-packages/pandas/io/json/_normalize.py in _recursive_extract(data, path, seen_meta, level)
#     330                                     "Try running with errors='ignore' as key "
#     331                                     f"{e} is not always present"
# --> 332                                 ) from e
#     333                     meta_vals[key].append(meta_val)
#     334                 records.extend(recs)
#
# KeyError: "Try running with errors='ignore' as key 'math' is not always present"

# %%
pd.json_normalize(
    data, 
    record_path =['students'], 
    meta=['class', 'room', ['info', 'teachers', 'math']],
    errors='ignore'
)
# Out:
#          name sex   class    room info.teachers.math
# 0         Tom   M  Year 1  Yellow         Rick Scott
# 1       James   M  Year 1  Yellow         Rick Scott
# 2        Tony   M  Year 2    Blue                NaN
# 3  Jacqueline   F  Year 2    Blue                NaN

# %% [markdown]
# ### 5. Custom separator using `sep`

# %%
data = [
    { 
        'class': 'Year 1', 
        'student count': 20, 
        'room': 'Yellow',
        'info': {
            'teachers': { 'math': 'Rick Scott', 'physics': 'Elon Mask' }
        },
        'students': [
            { 'name': 'Tom', 'sex': 'M', 'grades': { 'math': 66, 'physics': 77 } },
            { 'name': 'James', 'sex': 'M', 'grades': { 'math': 80, 'physics': 78 } },
        ]
    },
    { 
        'class': 'Year 2', 
        'student count': 25, 
        'room': 'Blue',
        'info': {
            'teachers': { 'math': 'Alan Turing', 'physics': 'Albert Einstein' }
        },
        'students': [
            { 'name': 'Tony', 'sex': 'M' },
            { 'name': 'Jacqueline', 'sex': 'F' },
        ]
    },
]

# %%
pd.json_normalize(
    data, 
    record_path =['students'], 
    meta=['class', 'room', ['info', 'teachers', 'math']],
    sep='->'
)
# Out:
#          name sex  grades->math  grades->physics   class    room  \
# 0         Tom   M          66.0             77.0  Year 1  Yellow
# 1       James   M          80.0             78.0  Year 1  Yellow
# 2        Tony   M           NaN              NaN  Year 2    Blue
# 3  Jacqueline   F           NaN              NaN  Year 2    Blue
#
#   info->teachers->math
# 0           Rick Scott
# 1           Rick Scott
# 2          Alan Turing
# 3          Alan Turing

# %% [markdown]
# ## 6. Adding prefix for meta and record data using `meta_prefix` and `record_prefix`

# %%
pd.json_normalize(
    data, 
    record_path=['students'], 
    meta=['class'],
    meta_prefix='meta-',
    record_prefix='student-'
)
# Out:
#   student-name student-sex  student-grades.math  student-grades.physics  \
# 0          Tom           M                 66.0                    77.0
# 1        James           M                 80.0                    78.0
# 2         Tony           M                  NaN                     NaN
# 3   Jacqueline           F                  NaN                     NaN
#
#   meta-class
# 0     Year 1
# 1     Year 1
# 2     Year 2
# 3     Year 2

# %% [markdown]
# ## 7. Working with a local file

# %%
import json
# load data using Python JSON module
with open('data/simple.json','r') as f:
    data = json.loads(f.read())
    
# Normalizing data
pd.json_normalize(data)
# Out:
#      id   name  math  physics  chemistry
# 0  A001    Tom    60       66         61
# 1  A002  James    89       76         51
# 2  A003  Jenny    79       90         78

# %% [markdown]
# ## 8. Working with a URL

# %%
import requests

URL = 'http://raw.githubusercontent.com/BindiChen/machine-learning/master/data-analysis/027-pandas-convert-json/data/simple.json'

data = json.loads(requests.get(URL).text)
pd.json_normalize(data)
# Out:
#      id   name  math  physics  chemistry
# 0  A001    Tom    60       66         61
# 1  A002  James    89       76         51
# 2  A003  Jenny    79       90         78
