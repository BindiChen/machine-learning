# %% [markdown]
# # Pandas `loc` and `iloc` for selecting data
#
# This is a notebook for the medium article [How to use `loc` and `iloc` for selecting data in Pandas](https://bindichen.medium.com/how-to-use-loc-and-iloc-for-selecting-data-in-pandas-bd09cb4c3d79)
#
# Please check out article for instructions
#
# **License**: [BSD 2-Clause](https://opensource.org/licenses/BSD-2-Clause)

# %%
import pandas as pd

# %%
df = pd.read_csv('data/data.csv', index_col=['Day'])
df
# Out:
#     Weather  Temperature  Wind  Humidity
# Day
# Mon   Sunny        12.79    13        30
# Tue   Sunny        19.67    28        96
# Wed   Sunny        17.51    16        20
# Thu  Cloudy        14.44    11        22
# Fri  Shower        10.51    26        79
# Sat  Shower        11.07    27        62
# Sun   Sunny        17.50    20        10

# %% [markdown]
# ## 1. Differences between loc and iloc
#
# The main distinction between `loc` and `iloc` is:
# * `loc` is label-based, which means that you have to specify rows and columns based on their row and column labels.
# * `iloc` is integer position-based, so you have to specify rows and columns by their integer position values (0-based integer position).

# %% [markdown]
# ## 2. Selecting via a single value

# %% [markdown]
# To get Fridays' temperature

# %%
# Pass label to `loc`
df.loc['Fri', 'Temperature']
# Out:
# 10.51

# %%
# The equivalent `iloc` statement should take row number 4 and column number 1
df.iloc[4, 1]
# Out:
# 10.51

# %% [markdown]
# Use `:` to return all data

# %%
# To get all rows
df.loc[:, 'Temperature']
# Out:
# Day
# Mon    12.79
# Tue    19.67
# Wed    17.51
# Thu    14.44
# Fri    10.51
# Sat    11.07
# Sun    17.50
# Name: Temperature, dtype: float64

# %%
# The equivalent `iloc` statement
df.iloc[:, 1]
# Out:
# Day
# Mon    12.79
# Tue    19.67
# Wed    17.51
# Thu    14.44
# Fri    10.51
# Sat    11.07
# Sun    17.50
# Name: Temperature, dtype: float64

# %%
# To get all columns
df.loc['Fri', :]
# Out:
# Weather        Shower
# Temperature     10.51
# Wind               26
# Humidity           79
# Name: Fri, dtype: object

# %%
# The equivalent `iloc` statement
df.iloc[4, :]
# Out:
# Weather        Shower
# Temperature     10.51
# Wind               26
# Humidity           79
# Name: Fri, dtype: object

# %% [markdown]
# ## 3. Selecting via a list of values

# %%
# Multiple rows
df.loc[['Thu', 'Fri'], 'Temperature']
# Out:
# Day
# Thu    14.44
# Fri    10.51
# Name: Temperature, dtype: float64

# %%
# Multiple columns
df.loc['Fri', ['Temperature', 'Wind']]
# Out:
# Temperature    10.51
# Wind              26
# Name: Fri, dtype: object

# %%
# Multiple rows using iloc
df.iloc[[3, 4], 1]
# Out:
# Day
# Thu    14.44
# Fri    10.51
# Name: Temperature, dtype: float64

# %%
# Multiple columns using iloc
df.iloc[4, [1, 2]]
# Out:
# Temperature    10.51
# Wind              26
# Name: Fri, dtype: object

# %%
# Multiple rows and columns
rows = ['Thu', 'Fri']
cols=['Temperature','Wind']

df.loc[rows, cols]
# Out:
#      Temperature  Wind
# Day
# Thu        14.44    11
# Fri        10.51    26

# %%
# the equivalent iloc statement
rows = [3, 4]
cols = [1, 2]
df.iloc[rows, cols]
# Out:
#      Temperature  Wind
# Day
# Thu        14.44    11
# Fri        10.51    26

# %% [markdown]
# ## 4. Selecting a range of data via slice

# %% [markdown]
# For loc, we can use the syntax `A:B` to select data from label `A` to label `B` (Both `A` and `B` are included):

# %%
# Slicing column labels
rows=['Thu', 'Fri']
df.loc[rows, 'Temperature':'Humidity' ]
# Out:
#      Temperature  Wind  Humidity
# Day
# Thu        14.44    11        22
# Fri        10.51    26        79

# %%
# Slicing row labels
cols = ['Temperature', 'Wind']
df.loc['Mon':'Thu', cols]
# Out:
#      Temperature  Wind
# Day
# Mon        12.79    13
# Tue        19.67    28
# Wed        17.51    16
# Thu        14.44    11

# %% [markdown]
# We can use the syntax `A:B:S` to select data from label `A` to label `B` with step size `S` (Both `A` and `B` are included):

# %%
# Slicing with step
df.loc['Mon':'Fri':2 , :]
# Out:
#     Weather  Temperature  Wind  Humidity
# Day
# Mon   Sunny        12.79    13        30
# Wed   Sunny        17.51    16        20
# Fri  Shower        10.51    26        79

# %% [markdown]
# With iloc, we can also use the syntax `n:m` to select data from position `n` (included) to position `m` (excluded).

# %%
df.iloc[[1, 2], 0 : 3]
# Out:
#     Weather  Temperature  Wind
# Day
# Tue   Sunny        19.67    28
# Wed   Sunny        17.51    16

# %%
df.iloc[0:4:2, :]
# Out:
#     Weather  Temperature  Wind  Humidity
# Day
# Mon   Sunny        12.79    13        30
# Wed   Sunny        17.51    16        20

# %% [markdown]
# ## 5. Selecting via conditions and callable

# %% [markdown]
# ### 5.2 Conditions

# %%
# One condition
df.loc[df.Humidity > 50, :]
# Out:
#     Weather  Temperature  Wind  Humidity
# Day
# Tue   Sunny        19.67    28        96
# Fri  Shower        10.51    26        79
# Sat  Shower        11.07    27        62

# %%
## multiple conditions
df.loc[
    (df.Humidity > 50) & (df.Weather == 'Shower'), 
    ['Temperature','Wind'],
]
# Out:
#      Temperature  Wind
# Day
# Fri        10.51    26
# Sat        11.07    27

# %%
# Getting ValueError
df.iloc[df.Humidity > 50, :]
# Out:
# ---------------------------------------------------------------------------
# ValueError                                Traceback (most recent call last)
# ~/anaconda3/envs/tf-tutorial/lib/python3.7/site-packages/pandas/core/indexing.py in _has_valid_tuple(self, key)
#     701             try:
# --> 702                 self._validate_key(k, i)
#     703             except ValueError as err:
#
# ~/anaconda3/envs/tf-tutorial/lib/python3.7/site-packages/pandas/core/indexing.py in _validate_key(self, key, axis)
#    1343                 raise ValueError(
# -> 1344                     "iLocation based boolean indexing cannot use "
#    1345                     "an indexable as a mask"
#
# ValueError: iLocation based boolean indexing cannot use an indexable as a mask
#
# The above exception was the direct cause of the following exception:
#
# ValueError                                Traceback (most recent call last)
# <ipython-input-22-6e7f6c6a434d> in <module>
#       1 # Getting ValueError
# ----> 2 df.iloc[df.Humidity > 50, :]
#
# ~/anaconda3/envs/tf-tutorial/lib/python3.7/site-packages/pandas/core/indexing.py in __getitem__(self, key)
#     871                     # AttributeError for IntervalTree get_value
#     872                     pass
# --> 873             return self._getitem_tuple(key)
#     874         else:
#     875             # we by definition only have the 0th axis
#
# ~/anaconda3/envs/tf-tutorial/lib/python3.7/site-packages/pandas/core/indexing.py in _getitem_tuple(self, tup)
#    1441     def _getitem_tuple(self, tup: Tuple):
#    1442
# -> 1443         self._has_valid_tuple(tup)
#    1444         try:
#    1445             return self._getitem_lowerdim(tup)
#
# ~/anaconda3/envs/tf-tutorial/lib/python3.7/site-packages/pandas/core/indexing.py in _has_valid_tuple(self, key)
#     705                     "Location based indexing can only have "
#     706                     f"[{self._valid_types}] types"
# --> 707                 ) from err
#     708
#     709     def _is_nested_tuple_indexer(self, tup: Tuple) -> bool:
#
# ValueError: Location based indexing can only have [integer, integer slice (START point is INCLUDED, END point is EXCLUDED), listlike of integers, boolean array] types

# %%
# Single condition
df.iloc[list(df.Humidity > 50)]
# Out:
#     Weather  Temperature  Wind  Humidity
# Day
# Tue   Sunny        19.67    28        96
# Fri  Shower        10.51    26        79
# Sat  Shower        11.07    27        62

# %%
## multiple conditions
df.iloc[
    list((df.Humidity > 50) & (df.Weather == 'Shower')), 
    :,
]
# Out:
#     Weather  Temperature  Wind  Humidity
# Day
# Fri  Shower        10.51    26        79
# Sat  Shower        11.07    27        62

# %% [markdown]
# ### 5.2 Callable

# %%
# Selecting columns
df.loc[:, lambda df: ['Humidity', 'Wind']]
# Out:
#      Humidity  Wind
# Day
# Mon        30    13
# Tue        96    28
# Wed        20    16
# Thu        22    11
# Fri        79    26
# Sat        62    27
# Sun        10    20

# %%
# With condition
df.loc[lambda df: df.Humidity > 50, :]
# Out:
#     Weather  Temperature  Wind  Humidity
# Day
# Tue   Sunny        19.67    28        96
# Fri  Shower        10.51    26        79
# Sat  Shower        11.07    27        62

# %%
df.iloc[lambda df: [0,1], :]
# Out:
#     Weather  Temperature  Wind  Humidity
# Day
# Mon   Sunny        12.79    13        30
# Tue   Sunny        19.67    28        96

# %%
df.iloc[lambda df: list(df.Humidity > 50), :]
# Out:
#     Weather  Temperature  Wind  Humidity
# Day
# Tue   Sunny        19.67    28        96
# Fri  Shower        10.51    26        79
# Sat  Shower        11.07    27        62

# %% [markdown]
# ## 6. `loc` and `iloc` are interchangeable when labels are 0-based integers

# %%
df = pd.read_csv(
    'data/data.csv', 
    header=None, 
    skiprows=[0],
)
df
# Out:
#      0       1      2   3   4
# 0  Mon   Sunny  12.79  13  30
# 1  Tue   Sunny  19.67  28  96
# 2  Wed   Sunny  17.51  16  20
# 3  Thu  Cloudy  14.44  11  22
# 4  Fri  Shower  10.51  26  79
# 5  Sat  Shower  11.07  27  62
# 6  Sun   Sunny  17.50  20  10

# %% [markdown]
# Now, `loc`, a label-based data selector, can accept a single integer and a list of integer values.

# %%
df.loc[1, 2]
# Out:
# 19.67

# %%
df.loc[1, [1, 2]]
# Out:
# 1    Sunny
# 2    19.67
# Name: 1, dtype: object

# %% [markdown]
# `loc` and `iloc` are interchangeable when selecting via a single value or a list of values.

# %%
df.loc[1, 2] == df.iloc[1, 2]
# Out:
# True

# %%
df.loc[1, [1, 2]] == df.iloc[1, [1, 2]]
# Out:
# 1    True
# 2    True
# Name: 1, dtype: bool
